# %% [markdown]
# # 01_fit_msaa_flexible_within_across_spatial_temporal.ipynb
#
# This notebook fits **multi-subject archetypal analysis (MS-AA)** with two user-controlled switches:
#
# - `ANALYSIS_TYPE = "spatial"` or `"temporal"`
# - `FIT_SCOPE = "within"` or `"across"`
#
# ## Conventions used here
#
# Let each subject's original matrix be:
#
# \[
# X^{(s)} \in \mathbb{R}^{T 	imes V}
# \]
#
# where:
# - `T` = timepoints
# - `V` = nodes
#
# ### Spatial AA
# Fit directly on `X^(s)`:
# - `sXC`: `T x K`
# - `S`: `K x V`
#
# Interpretation:
# - shared **temporal archetypes / motifs**
# - subject-specific **spatial expression**
#
# ### Temporal AA
# Fit on the transposed subject matrix `X^(s).T`:
# - `sXC`: `V x K`
# - `S`: `K x T`
#
# Interpretation:
# - shared **spatial archetypes / motifs**
# - subject-specific **time-varying coefficients**
#
# ## Scope options
#
# ### `FIT_SCOPE = "within"`
# Fits **one model per condition**.
#
# ### `FIT_SCOPE = "across"`
# Fits **one joint model across all selected conditions**.
#
# Outputs are saved as `.npz` files with names that encode:
# - analysis type
# - fit scope
# - condition name (for within-condition fits)
# - K value

# %%
# =========================
# USER SETTINGS
# =========================

ANALYSIS_TYPE = "spatial"   # "spatial" or "temporal"
FIT_SCOPE = "within"         # "within" or "across"

K_VALUES = [10, 25, 50, 75, 100]
CONDITIONS_TO_USE = ["intact", "word", "rest"]
TRIM_REST_BY = 100
RNG_SEED = 42

PIEMAN_MAT_PATH = "data/pieman/raw/pieman_data.mat"
POSTERIOR_MAT_PATH = "data/pieman/raw/pieman_posterior_K700.mat"
HELPERS_DIR = "helpers"
HYPERTOOLS_NORMALIZE_PATH = "hypertools/normalize.py"

OUTPUT_DIR = "msaa_flexible_outputs_npz"

MSAA_OPTS = dict(
    maxiter=200,
    conv_crit=1e-6,
    fix_var_iter=5,
    heteroscedastic=False,
    use_gpu=False,
    rngSEED=RNG_SEED,
)

assert ANALYSIS_TYPE in {"spatial", "temporal"}
assert FIT_SCOPE in {"within", "across"}


# Robustness / restart controls
SKIP_EXISTING = True          # skip fits that are already saved
STOP_ON_ERROR = False         # keep going if one fit fails
VERBOSE_PROGRESS = True

# %%
# %matplotlib inline
import os, sys, importlib.util
import numpy as np
import pandas as pd
from scipy.io import loadmat

HT_NORMALIZE_AVAILABLE = False
try:
    spec = importlib.util.spec_from_file_location("normalize", HYPERTOOLS_NORMALIZE_PATH)
    ht = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(ht)
    HT_NORMALIZE_AVAILABLE = True
except Exception:
    ht = None

sys.path.append(HELPERS_DIR)
from MultiSubject_AA import Subject, multi_subject_aa

os.makedirs(OUTPUT_DIR, exist_ok=True)
print("Ready.")
print("ANALYSIS_TYPE =", ANALYSIS_TYPE)
print("FIT_SCOPE     =", FIT_SCOPE)
# Out:
# Ready.
# ANALYSIS_TYPE = spatial
# FIT_SCOPE     = within

# %%
def to_float_array(x):
    return np.array(x, dtype=float)

def array_cutter(data_list, cut_length):
    out = [to_float_array(x).copy() for x in data_list]
    if cut_length <= 0:
        return out
    return [x[:-cut_length] for x in out]

def coerce_TxV(x):
    x = to_float_array(x)
    if x.ndim != 2:
        raise ValueError(f"Expected 2D array, got {x.shape}")
    T, V = x.shape
    if V < T:
        x = x.T
    x = x - x.mean(axis=0, keepdims=True)
    return x.astype(np.float32, copy=False)

def normalize_across_fallback(subject_list, eps=1e-8):
    subj = [coerce_TxV(x) for x in subject_list]
    stacked = np.vstack(subj)
    mu = stacked.mean(axis=0, keepdims=True)
    sd = stacked.std(axis=0, keepdims=True) + eps
    return [((x - mu) / sd).astype(np.float32, copy=False) for x in subj]

def normalize_subject_list(subject_list):
    subj = [coerce_TxV(x) for x in subject_list]
    if HT_NORMALIZE_AVAILABLE:
        try:
            return ht.normalize(subj, normalize="across")
        except Exception:
            return normalize_across_fallback(subj)
    return normalize_across_fallback(subj)

# %%
def load_condition_data():
    pieman_data = loadmat(PIEMAN_MAT_PATH)
    data, conds = [], []

    for c in CONDITIONS_TO_USE:
        next_data = list(map(lambda i: pieman_data[c][:, i][0], np.arange(pieman_data[c].shape[1])))
        data.extend(next_data)
        conds.extend([c] * len(next_data))

    conds_array = np.array(conds)
    condition_data = {}

    for c in CONDITIONS_TO_USE:
        cur = [data[i] for i in np.where(conds_array == c)[0]]
        if c == "rest" and TRIM_REST_BY > 0:
            cur = array_cutter(cur, TRIM_REST_BY)
        condition_data[c] = normalize_subject_list(cur)

    return condition_data

condition_data = load_condition_data()

print("Condition counts:")
for c in CONDITIONS_TO_USE:
    print(c, len(condition_data[c]), "example shape:", np.asarray(condition_data[c][0]).shape)

posterior = loadmat(POSTERIOR_MAT_PATH)
centers = to_float_array(posterior['posterior']['centers'][0][0][0][0][0])
widths = to_float_array(list(posterior['posterior']['widths'][0][0][0][0][0][:, 0].T)).ravel()
print("centers shape:", centers.shape, "| widths shape:", widths.shape)
# Out:
# Condition counts:
# intact 36 example shape: (300, 700)
# word 36 example shape: (300, 700)
# rest 36 example shape: (300, 700)
# centers shape: (700, 3) | widths shape: (700,)

# %%
def orient_subject_matrix(X_raw, analysis_type):
    Xtv = coerce_TxV(X_raw)  # T x V
    if analysis_type == "spatial":
        return Xtv
    elif analysis_type == "temporal":
        return Xtv.T
    else:
        raise ValueError("analysis_type must be 'spatial' or 'temporal'")

def build_subject_objects(subject_list, analysis_type):
    subj_objs = []
    for X_raw in subject_list:
        X_oriented = orient_subject_matrix(X_raw, analysis_type)
        subj_objs.append(Subject(X=X_oriented, sX=X_oriented))
    return subj_objs

def expected_shape_string(example_X_raw, analysis_type, K):
    Xtv = coerce_TxV(example_X_raw)
    T, V = Xtv.shape
    if analysis_type == "spatial":
        return f"sXC ~ ({T}, {K}), S ~ ({K}, {V})"
    else:
        return f"sXC ~ ({V}, {K}), S ~ ({K}, {T})"

# %%
def fit_msaa(subject_list, K, analysis_type, opts=None, verbose=True):
    opts = dict(MSAA_OPTS if opts is None else opts)
    subj_objs = build_subject_objects(subject_list, analysis_type)
    results_subj, C, cost_fun, varexpl, secs = multi_subject_aa(
        subj_objs,
        noc=K,
        opts=opts,
    )

    if verbose:
        print(f"[{analysis_type.upper()} AA] K={K} | VarExpl={varexpl*100:.2f}%")
        print("subj0 sXC shape:", np.asarray(results_subj[0]["sXC"]).shape)
        print("subj0 S shape:", np.asarray(results_subj[0]["S"]).shape)
        print("Expected:", expected_shape_string(subject_list[0], analysis_type, K))

    return {
        "results_subj": results_subj,
        "C": C,
        "cost_fun": cost_fun,
        "varexpl": varexpl,
        "secs": secs,
        "K": K,
    }

def save_fit_npz(save_path, fit_res, condition_labels_str):
    np.savez_compressed(
        save_path,
        K=np.array(fit_res["K"]),
        results_subj=np.array(fit_res["results_subj"], dtype=object),
        C=np.array(fit_res["C"], dtype=object),
        cost_fun=np.array(fit_res["cost_fun"], dtype=object),
        varexpl=np.array(fit_res["varexpl"]),
        secs=np.array(fit_res["secs"]),
        condition_labels_str=np.array(condition_labels_str, dtype=object),
        condition_codes=np.array(pd.Categorical(condition_labels_str).codes),
        condition_names=np.array(sorted(np.unique(condition_labels_str)), dtype=object),
        analysis_type=np.array(ANALYSIS_TYPE, dtype=object),
        fit_scope=np.array(FIT_SCOPE, dtype=object),
        centers=np.array(centers),
        widths=np.array(widths),
    )

# %%
def get_fit_jobs(condition_data, fit_scope):
    jobs = []
    if fit_scope == "within":
        for cond_name, subject_list in condition_data.items():
            jobs.append({
                "job_name": cond_name,
                "subject_list": subject_list,
                "condition_labels_str": [cond_name] * len(subject_list),
            })
    elif fit_scope == "across":
        all_subjects = []
        all_labels = []
        for cond_name, subject_list in condition_data.items():
            all_subjects.extend(subject_list)
            all_labels.extend([cond_name] * len(subject_list))
        jobs.append({
            "job_name": "acrossCond",
            "subject_list": all_subjects,
            "condition_labels_str": all_labels,
        })
    else:
        raise ValueError("fit_scope must be 'within' or 'across'")
    return jobs

jobs = get_fit_jobs(condition_data, FIT_SCOPE)
print("Jobs to run:")
for job in jobs:
    print("-", job["job_name"], "| n subjects =", len(job["subject_list"]))
# Out:
# Jobs to run:
# - intact | n subjects = 36
# - word | n subjects = 36
# - rest | n subjects = 36

# %%
def job_output_path(output_dir, analysis_type, fit_scope, job_name, K):
    filename = f"{analysis_type}AA_{fit_scope}_{job_name}_K{K}.npz"
    return os.path.join(output_dir, filename)

def print_job_header(job_name, K, analysis_type, fit_scope, subject_list):
    print("=" * 80)
    print(f"Starting job: analysis={analysis_type} | scope={fit_scope} | target={job_name} | K={K}")
    print(f"n_subjects={len(subject_list)} | example_shape={np.asarray(subject_list[0]).shape}")
    print("=" * 80)

# %%
saved_paths = []
failed_jobs = []

for K in K_VALUES:
    print("\n" + "#" * 90)
    print(f"Beginning all jobs for K={K}")
    print("#" * 90)

    for job in jobs:
        job_name = job["job_name"]
        subject_list = job["subject_list"]
        condition_labels_str = job["condition_labels_str"]

        save_path = job_output_path(OUTPUT_DIR, ANALYSIS_TYPE, FIT_SCOPE, job_name, K)

        if SKIP_EXISTING and os.path.exists(save_path):
            print(f"Skipping existing: {save_path}")
            saved_paths.append(save_path)
            continue

        if VERBOSE_PROGRESS:
            print_job_header(job_name, K, ANALYSIS_TYPE, FIT_SCOPE, subject_list)

        try:
            fit_res = fit_msaa(subject_list, K, ANALYSIS_TYPE, opts=MSAA_OPTS, verbose=True)
            save_fit_npz(save_path, fit_res, condition_labels_str)
            saved_paths.append(save_path)
            print("Saved:", save_path)
        except Exception as e:
            failed_jobs.append({
                "job_name": job_name,
                "K": K,
                "analysis_type": ANALYSIS_TYPE,
                "fit_scope": FIT_SCOPE,
                "error_type": type(e).__name__,
                "error_message": str(e),
            })
            print(f"FAILED: job={job_name}, K={K}, error={type(e).__name__}: {e}")
            if STOP_ON_ERROR:
                raise

print("\nFinished.")
print("Saved paths:")
for p in saved_paths:
    print(" -", p)

if failed_jobs:
    print("\nFailed jobs:")
    for fj in failed_jobs:
        print(fj)

saved_paths, failed_jobs
# Out:
# ##########################################################################################
# Beginning all jobs for K=10
# ##########################################################################################
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=intact | K=10
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# [SPATIAL AA] K=10 | VarExpl=33.69%
# subj0 sXC shape: (300, 10)
# subj0 S shape: (10, 700)
# Expected: sXC ~ (300, 10), S ~ (10, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_intact_K10.npz
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=word | K=10
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# [SPATIAL AA] K=10 | VarExpl=37.13%
# subj0 sXC shape: (300, 10)
# subj0 S shape: (10, 700)
# Expected: sXC ~ (300, 10), S ~ (10, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_word_K10.npz
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=rest | K=10
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# [SPATIAL AA] K=10 | VarExpl=26.26%
# subj0 sXC shape: (300, 10)
# subj0 S shape: (10, 700)
# Expected: sXC ~ (300, 10), S ~ (10, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_rest_K10.npz
#
# ##########################################################################################
# Beginning all jobs for K=25
# ##########################################################################################
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=intact | K=25
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=25 | VarExpl=40.86%
# subj0 sXC shape: (300, 25)
# subj0 S shape: (25, 700)
# Expected: sXC ~ (300, 25), S ~ (25, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_intact_K25.npz
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=word | K=25
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=25 | VarExpl=44.84%
# subj0 sXC shape: (300, 25)
# subj0 S shape: (25, 700)
# Expected: sXC ~ (300, 25), S ~ (25, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_word_K25.npz
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=rest | K=25
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=25 | VarExpl=34.05%
# subj0 sXC shape: (300, 25)
# subj0 S shape: (25, 700)
# Expected: sXC ~ (300, 25), S ~ (25, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_rest_K25.npz
#
# ##########################################################################################
# Beginning all jobs for K=50
# ##########################################################################################
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=intact | K=50
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=50 | VarExpl=47.41%
# subj0 sXC shape: (300, 50)
# subj0 S shape: (50, 700)
# Expected: sXC ~ (300, 50), S ~ (50, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_intact_K50.npz
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=word | K=50
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=50 | VarExpl=50.64%
# subj0 sXC shape: (300, 50)
# subj0 S shape: (50, 700)
# Expected: sXC ~ (300, 50), S ~ (50, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_word_K50.npz
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=rest | K=50
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=50 | VarExpl=42.24%
# subj0 sXC shape: (300, 50)
# subj0 S shape: (50, 700)
# Expected: sXC ~ (300, 50), S ~ (50, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_rest_K50.npz
#
# ##########################################################################################
# Beginning all jobs for K=75
# ##########################################################################################
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=intact | K=75
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=75 | VarExpl=52.30%
# subj0 sXC shape: (300, 75)
# subj0 S shape: (75, 700)
# Expected: sXC ~ (300, 75), S ~ (75, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_intact_K75.npz
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=word | K=75
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=75 | VarExpl=55.63%
# subj0 sXC shape: (300, 75)
# subj0 S shape: (75, 700)
# Expected: sXC ~ (300, 75), S ~ (75, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_word_K75.npz
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=rest | K=75
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=75 | VarExpl=46.96%
# subj0 sXC shape: (300, 75)
# subj0 S shape: (75, 700)
# Expected: sXC ~ (300, 75), S ~ (75, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_rest_K75.npz
#
# ##########################################################################################
# Beginning all jobs for K=100
# ##########################################################################################
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=intact | K=100
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=100 | VarExpl=56.55%
# subj0 sXC shape: (300, 100)
# subj0 S shape: (100, 700)
# Expected: sXC ~ (300, 100), S ~ (100, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_intact_K100.npz
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=word | K=100
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=100 | VarExpl=59.36%
# subj0 sXC shape: (300, 100)
# subj0 S shape: (100, 700)
# Expected: sXC ~ (300, 100), S ~ (100, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_word_K100.npz
# ================================================================================
# Starting job: analysis=spatial | scope=within | target=rest | K=100
# n_subjects=36 | example_shape=(300, 700)
# ================================================================================
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/anaconda3/envs/archs/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [SPATIAL AA] K=100 | VarExpl=51.14%
# subj0 sXC shape: (300, 100)
# subj0 S shape: (100, 700)
# Expected: sXC ~ (300, 100), S ~ (100, 700)
# Saved: msaa_flexible_outputs_npz/spatialAA_within_rest_K100.npz
#
# Finished.
# Saved paths:
#  - msaa_flexible_outputs_npz/spatialAA_within_intact_K10.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_word_K10.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_rest_K10.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_intact_K25.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_word_K25.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_rest_K25.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_intact_K50.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_word_K50.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_rest_K50.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_intact_K75.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_word_K75.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_rest_K75.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_intact_K100.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_word_K100.npz
#  - msaa_flexible_outputs_npz/spatialAA_within_rest_K100.npz
# (['msaa_flexible_outputs_npz/spatialAA_within_intact_K10.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_word_K10.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_rest_K10.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_intact_K25.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_word_K25.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_rest_K25.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_intact_K50.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_word_K50.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_rest_K50.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_intact_K75.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_word_K75.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_rest_K75.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_intact_K100.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_word_K100.npz',
#   'msaa_flexible_outputs_npz/spatialAA_within_rest_K100.npz'],
#  [])

# %% [markdown]
# ## Output naming examples
#
# ### Spatial AA, within-condition
# - `spatialAA_within_intact_K50.npz`
# - `spatialAA_within_word_K50.npz`
# - `spatialAA_within_rest_K50.npz`
#
# ### Temporal AA, within-condition
# - `temporalAA_within_intact_K50.npz`
# - `temporalAA_within_word_K50.npz`
# - `temporalAA_within_rest_K50.npz`
#
# ### Spatial AA, across-condition
# - `spatialAA_across_acrossCond_K50.npz`
#
# ### Temporal AA, across-condition
# - `temporalAA_across_acrossCond_K50.npz`

# %% [markdown]
# ## Suggested usage
#
# ### Run within-condition temporal AA
# ```python
# ANALYSIS_TYPE = "temporal"
# FIT_SCOPE = "within"
# ```
#
# ### Run within-condition spatial AA
# ```python
# ANALYSIS_TYPE = "spatial"
# FIT_SCOPE = "within"
# ```
#
# ### Run across-condition temporal AA
# ```python
# ANALYSIS_TYPE = "temporal"
# FIT_SCOPE = "across"
# ```
#
# ### Run across-condition spatial AA
# ```python
# ANALYSIS_TYPE = "spatial"
# FIT_SCOPE = "across"
# ```
